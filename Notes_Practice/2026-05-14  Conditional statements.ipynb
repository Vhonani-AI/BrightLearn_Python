# %%
score = 75


if score >= 80: #ranges 80 - 100
    print("Distinction")
elif score >= 60: #ranges 60 - 80
    print("Merit")
elif score >= 50:#ranges 50 - 60
    print("Pass")
else:#ranges 0 - 50
    print("Fail")
