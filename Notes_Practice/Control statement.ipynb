# %%
#List
products = ["Bread", "Milk", "Bread", "Juice"]

#Tuple
location = (-26.2, 28.0)

#Set
Unique_customers = {"c001", "c002", "c003"}

#Dictionary
customers = {
            "name": "Sarah",
            "age": 24,
            "age": 26,
            "location": "Johannesburg"         
            }

# %%
#loop - used instead of selecting everything

for item in products:
    print(item)

# %%
for item in customers:
    print(item)
